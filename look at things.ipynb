# %%
from glob import glob

# %%
elecs = glob("electrons/time_*")
elecs = map(loadtxt,elecs)
# Out:
# /usr/local/Cellar/python/2.7.6/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/numpy/lib/npyio.py:809: UserWarning: loadtxt: Empty input file: "electrons/time_106.txt"
#   warnings.warn('loadtxt: Empty input file: "%s"' % fname)

# %%
for j in range(0,60,5):
    
    loglog(elecs[j][:,0],elecs[j][:,1])
    
ylim(bottom=1E-17)
#loglog(elecs[0][:,0],elecs[0][:,0]*elecs[0][:,1])
# Out:
# (1e-17, 100000.0)

# %%
for j in range(0,5):
    
    loglog(elecs[j][:,0],elecs[j][:,1])
#loglog(elecs[0][:,0],elecs[0][:,0]*elecs[0][:,1])

# %%
test0 = loadtxt("photons/test0.txt")
test1 = loadtxt("photons/test1.txt")
test2 = loadtxt("photons/test2.txt")
testSum = test0[:,1] +test1[:,1] +test2[:,1]

# %%
loglog(test0[:,0],test0[:,0]**2*test0[:,1])
loglog(test1[:,0],test1[:,0]**2*test1[:,1])
loglog(test2[:,0],test2[:,0]**2*test2[:,1])
loglog(test2[:,0],test2[:,0]**2*testSum)
ylim(bottom=1E24)
# Out:
# (1e+24, 9.9999999999999995e+32)
